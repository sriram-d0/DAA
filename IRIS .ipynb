# %% [markdown]
# The Iris flower data set is an example of an open data. It is also called Fisher's Iris data set as this data set was introduced by the British statistician and biologist Ronald Fisher in 1936. The Iris data set consists of 50 samples from each of the three species of the flower Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured for each sample: the length and the width of the sepals and petals, in centimeters. Based on the combination of these four features, Fisher developed a model to distinguish one species from each other. The full data set is freely available on UCI Machine Learning Repository at https://archive.ics.uci.edu/ml/datasets/iris.
#
# The header is : sepal length, sepal width, petal length, petal width, iris, Species No. It has  value 1 for Iris setosa, 2 for Iris virginica and 3 for Iris versicolor.

# %% [markdown]
# 1. Load the data in the file Iris.txt in a 2-D array called iris.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
iris=np.loadtxt("/content/drive/MyDrive/SEM 5/DA/SOLUTIONSS/iris.data",delimiter=",",dtype='str')
print(iris)
# Out:
# [['5.1' '3.5' '1.4' '0.2' 'Iris-setosa']
#  ['4.9' '3.0' '1.4' '0.2' 'Iris-setosa']
#  ['4.7' '3.2' '1.3' '0.2' 'Iris-setosa']
#  ['4.6' '3.1' '1.5' '0.2' 'Iris-setosa']
#  ['5.0' '3.6' '1.4' '0.2' 'Iris-setosa']
#  ['5.4' '3.9' '1.7' '0.4' 'Iris-setosa']
#  ['4.6' '3.4' '1.4' '0.3' 'Iris-setosa']
#  ['5.0' '3.4' '1.5' '0.2' 'Iris-setosa']
#  ['4.4' '2.9' '1.4' '0.2' 'Iris-setosa']
#  ['4.9' '3.1' '1.5' '0.1' 'Iris-setosa']
#  ['5.4' '3.7' '1.5' '0.2' 'Iris-setosa']
#  ['4.8' '3.4' '1.6' '0.2' 'Iris-setosa']
#  ['4.8' '3.0' '1.4' '0.1' 'Iris-setosa']
#  ['4.3' '3.0' '1.1' '0.1' 'Iris-setosa']
#  ['5.8' '4.0' '1.2' '0.2' 'Iris-setosa']
#  ['5.7' '4.4' '1.5' '0.4' 'Iris-setosa']
#  ['5.4' '3.9' '1.3' '0.4' 'Iris-setosa']
#  ['5.1' '3.5' '1.4' '0.3' 'Iris-setosa']
#  ['5.7' '3.8' '1.7' '0.3' 'Iris-setosa']
#  ['5.1' '3.8' '1.5' '0.3' 'Iris-setosa']
#  ['5.4' '3.4' '1.7' '0.2' 'Iris-setosa']
#  ['5.1' '3.7' '1.5' '0.4' 'Iris-setosa']
#  ['4.6' '3.6' '1.0' '0.2' 'Iris-setosa']
#  ['5.1' '3.3' '1.7' '0.5' 'Iris-setosa']
#  ['4.8' '3.4' '1.9' '0.2' 'Iris-setosa']
#  ['5.0' '3.0' '1.6' '0.2' 'Iris-setosa']
#  ['5.0' '3.4' '1.6' '0.4' 'Iris-setosa']
#  ['5.2' '3.5' '1.5' '0.2' 'Iris-setosa']
#  ['5.2' '3.4' '1.4' '0.2' 'Iris-setosa']
#  ['4.7' '3.2' '1.6' '0.2' 'Iris-setosa']
#  ['4.8' '3.1' '1.6' '0.2' 'Iris-setosa']
#  ['5.4' '3.4' '1.5' '0.4' 'Iris-setosa']
#  ['5.2' '4.1' '1.5' '0.1' 'Iris-setosa']
#  ['5.5' '4.2' '1.4' '0.2' 'Iris-setosa']
#  ['4.9' '3.1' '1.5' '0.1' 'Iris-setosa']
#  ['5.0' '3.2' '1.2' '0.2' 'Iris-setosa']
#  ['5.5' '3.5' '1.3' '0.2' 'Iris-setosa']
#  ['4.9' '3.1' '1.5' '0.1' 'Iris-setosa']
#  ['4.4' '3.0' '1.3' '0.2' 'Iris-setosa']
#  ['5.1' '3.4' '1.5' '0.2' 'Iris-setosa']
#  ['5.0' '3.5' '1.3' '0.3' 'Iris-setosa']
#  ['4.5' '2.3' '1.3' '0.3' 'Iris-setosa']
#  ['4.4' '3.2' '1.3' '0.2' 'Iris-setosa']
#  ['5.0' '3.5' '1.6' '0.6' 'Iris-setosa']
#  ['5.1' '3.8' '1.9' '0.4' 'Iris-setosa']
#  ['4.8' '3.0' '1.4' '0.3' 'Iris-setosa']
#  ['5.1' '3.8' '1.6' '0.2' 'Iris-setosa']
#  ['4.6' '3.2' '1.4' '0.2' 'Iris-setosa']
#  ['5.3' '3.7' '1.5' '0.2' 'Iris-setosa']
#  ['5.0' '3.3' '1.4' '0.2' 'Iris-setosa']
#  ['7.0' '3.2' '4.7' '1.4' 'Iris-versicolor']
#  ['6.4' '3.2' '4.5' '1.5' 'Iris-versicolor']
#  ['6.9' '3.1' '4.9' '1.5' 'Iris-versicolor']
#  ['5.5' '2.3' '4.0' '1.3' 'Iris-versicolor']
#  ['6.5' '2.8' '4.6' '1.5' 'Iris-versicolor']
#  ['5.7' '2.8' '4.5' '1.3' 'Iris-versicolor']
#  ['6.3' '3.3' '4.7' '1.6' 'Iris-versicolor']
#  ['4.9' '2.4' '3.3' '1.0' 'Iris-versicolor']
#  ['6.6' '2.9' '4.6' '1.3' 'Iris-versicolor']
#  ['5.2' '2.7' '3.9' '1.4' 'Iris-versicolor']
#  ['5.0' '2.0' '3.5' '1.0' 'Iris-versicolor']
#  ['5.9' '3.0' '4.2' '1.5' 'Iris-versicolor']
#  ['6.0' '2.2' '4.0' '1.0' 'Iris-versicolor']
#  ['6.1' '2.9' '4.7' '1.4' 'Iris-versicolor']
#  ['5.6' '2.9' '3.6' '1.3' 'Iris-versicolor']
#  ['6.7' '3.1' '4.4' '1.4' 'Iris-versicolor']
#  ['5.6' '3.0' '4.5' '1.5' 'Iris-versicolor']
#  ['5.8' '2.7' '4.1' '1.0' 'Iris-versicolor']
#  ['6.2' '2.2' '4.5' '1.5' 'Iris-versicolor']
#  ['5.6' '2.5' '3.9' '1.1' 'Iris-versicolor']
#  ['5.9' '3.2' '4.8' '1.8' 'Iris-versicolor']
#  ['6.1' '2.8' '4.0' '1.3' 'Iris-versicolor']
#  ['6.3' '2.5' '4.9' '1.5' 'Iris-versicolor']
#  ['6.1' '2.8' '4.7' '1.2' 'Iris-versicolor']
#  ['6.4' '2.9' '4.3' '1.3' 'Iris-versicolor']
#  ['6.6' '3.0' '4.4' '1.4' 'Iris-versicolor']
#  ['6.8' '2.8' '4.8' '1.4' 'Iris-versicolor']
#  ['6.7' '3.0' '5.0' '1.7' 'Iris-versicolor']
#  ['6.0' '2.9' '4.5' '1.5' 'Iris-versicolor']
#  ['5.7' '2.6' '3.5' '1.0' 'Iris-versicolor']
#  ['5.5' '2.4' '3.8' '1.1' 'Iris-versicolor']
#  ['5.5' '2.4' '3.7' '1.0' 'Iris-versicolor']
#  ['5.8' '2.7' '3.9' '1.2' 'Iris-versicolor']
#  ['6.0' '2.7' '5.1' '1.6' 'Iris-versicolor']
#  ['5.4' '3.0' '4.5' '1.5' 'Iris-versicolor']
#  ['6.0' '3.4' '4.5' '1.6' 'Iris-versicolor']
#  ['6.7' '3.1' '4.7' '1.5' 'Iris-versicolor']
#  ['6.3' '2.3' '4.4' '1.3' 'Iris-versicolor']
#  ['5.6' '3.0' '4.1' '1.3' 'Iris-versicolor']
#  ['5.5' '2.5' '4.0' '1.3' 'Iris-versicolor']
#  ['5.5' '2.6' '4.4' '1.2' 'Iris-versicolor']
#  ['6.1' '3.0' '4.6' '1.4' 'Iris-versicolor']
#  ['5.8' '2.6' '4.0' '1.2' 'Iris-versicolor']
#  ['5.0' '2.3' '3.3' '1.0' 'Iris-versicolor']
#  ['5.6' '2.7' '4.2' '1.3' 'Iris-versicolor']
#  ['5.7' '3.0' '4.2' '1.2' 'Iris-versicolor']
#  ['5.7' '2.9' '4.2' '1.3' 'Iris-versicolor']
#  ['6.2' '2.9' '4.3' '1.3' 'Iris-versicolor']
#  ['5.1' '2.5' '3.0' '1.1' 'Iris-versicolor']
#  ['5.7' '2.8' '4.1' '1.3' 'Iris-versicolor']
#  ['6.3' '3.3' '6.0' '2.5' 'Iris-virginica']
#  ['5.8' '2.7' '5.1' '1.9' 'Iris-virginica']
#  ['7.1' '3.0' '5.9' '2.1' 'Iris-virginica']
#  ['6.3' '2.9' '5.6' '1.8' 'Iris-virginica']
#  ['6.5' '3.0' '5.8' '2.2' 'Iris-virginica']
#  ['7.6' '3.0' '6.6' '2.1' 'Iris-virginica']
#  ['4.9' '2.5' '4.5' '1.7' 'Iris-virginica']
#  ['7.3' '2.9' '6.3' '1.8' 'Iris-virginica']
#  ['6.7' '2.5' '5.8' '1.8' 'Iris-virginica']
#  ['7.2' '3.6' '6.1' '2.5' 'Iris-virginica']
#  ['6.5' '3.2' '5.1' '2.0' 'Iris-virginica']
#  ['6.4' '2.7' '5.3' '1.9' 'Iris-virginica']
#  ['6.8' '3.0' '5.5' '2.1' 'Iris-virginica']
#  ['5.7' '2.5' '5.0' '2.0' 'Iris-virginica']
#  ['5.8' '2.8' '5.1' '2.4' 'Iris-virginica']
#  ['6.4' '3.2' '5.3' '2.3' 'Iris-virginica']
#  ['6.5' '3.0' '5.5' '1.8' 'Iris-virginica']
#  ['7.7' '3.8' '6.7' '2.2' 'Iris-virginica']
#  ['7.7' '2.6' '6.9' '2.3' 'Iris-virginica']
#  ['6.0' '2.2' '5.0' '1.5' 'Iris-virginica']
#  ['6.9' '3.2' '5.7' '2.3' 'Iris-virginica']
#  ['5.6' '2.8' '4.9' '2.0' 'Iris-virginica']
#  ['7.7' '2.8' '6.7' '2.0' 'Iris-virginica']
#  ['6.3' '2.7' '4.9' '1.8' 'Iris-virginica']
#  ['6.7' '3.3' '5.7' '2.1' 'Iris-virginica']
#  ['7.2' '3.2' '6.0' '1.8' 'Iris-virginica']
#  ['6.2' '2.8' '4.8' '1.8' 'Iris-virginica']
#  ['6.1' '3.0' '4.9' '1.8' 'Iris-virginica']
#  ['6.4' '2.8' '5.6' '2.1' 'Iris-virginica']
#  ['7.2' '3.0' '5.8' '1.6' 'Iris-virginica']
#  ['7.4' '2.8' '6.1' '1.9' 'Iris-virginica']
#  ['7.9' '3.8' '6.4' '2.0' 'Iris-virginica']
#  ['6.4' '2.8' '5.6' '2.2' 'Iris-virginica']
#  ['6.3' '2.8' '5.1' '1.5' 'Iris-virginica']
#  ['6.1' '2.6' '5.6' '1.4' 'Iris-virginica']
#  ['7.7' '3.0' '6.1' '2.3' 'Iris-virginica']
#  ['6.3' '3.4' '5.6' '2.4' 'Iris-virginica']
#  ['6.4' '3.1' '5.5' '1.8' 'Iris-virginica']
#  ['6.0' '3.0' '4.8' '1.8' 'Iris-virginica']
#  ['6.9' '3.1' '5.4' '2.1' 'Iris-virginica']
#  ['6.7' '3.1' '5.6' '2.4' 'Iris-virginica']
#  ['6.9' '3.1' '5.1' '2.3' 'Iris-virginica']
#  ['5.8' '2.7' '5.1' '1.9' 'Iris-virginica']
#  ['6.8' '3.2' '5.9' '2.3' 'Iris-virginica']
#  ['6.7' '3.3' '5.7' '2.5' 'Iris-virginica']
#  ['6.7' '3.0' '5.2' '2.3' 'Iris-virginica']
#  ['6.3' '2.5' '5.0' '1.9' 'Iris-virginica']
#  ['6.5' '3.0' '5.2' '2.0' 'Iris-virginica']
#  ['6.2' '3.4' '5.4' '2.3' 'Iris-virginica']
#  ['5.9' '3.0' '5.1' '1.8' 'Iris-virginica']]

# %% [markdown]
# 2. Drop column whose index = 4 from the array iris.

# %%
import numpy as np
iris=np.loadtxt("/content/drive/MyDrive/SEM 5/DA/SOLUTIONSS/iris.data",delimiter=",",dtype='str')
iris=iris[:,:4]
print(iris)
# Out:
# [['5.1' '3.5' '1.4' '0.2']
#  ['4.9' '3.0' '1.4' '0.2']
#  ['4.7' '3.2' '1.3' '0.2']
#  ['4.6' '3.1' '1.5' '0.2']
#  ['5.0' '3.6' '1.4' '0.2']
#  ['5.4' '3.9' '1.7' '0.4']
#  ['4.6' '3.4' '1.4' '0.3']
#  ['5.0' '3.4' '1.5' '0.2']
#  ['4.4' '2.9' '1.4' '0.2']
#  ['4.9' '3.1' '1.5' '0.1']
#  ['5.4' '3.7' '1.5' '0.2']
#  ['4.8' '3.4' '1.6' '0.2']
#  ['4.8' '3.0' '1.4' '0.1']
#  ['4.3' '3.0' '1.1' '0.1']
#  ['5.8' '4.0' '1.2' '0.2']
#  ['5.7' '4.4' '1.5' '0.4']
#  ['5.4' '3.9' '1.3' '0.4']
#  ['5.1' '3.5' '1.4' '0.3']
#  ['5.7' '3.8' '1.7' '0.3']
#  ['5.1' '3.8' '1.5' '0.3']
#  ['5.4' '3.4' '1.7' '0.2']
#  ['5.1' '3.7' '1.5' '0.4']
#  ['4.6' '3.6' '1.0' '0.2']
#  ['5.1' '3.3' '1.7' '0.5']
#  ['4.8' '3.4' '1.9' '0.2']
#  ['5.0' '3.0' '1.6' '0.2']
#  ['5.0' '3.4' '1.6' '0.4']
#  ['5.2' '3.5' '1.5' '0.2']
#  ['5.2' '3.4' '1.4' '0.2']
#  ['4.7' '3.2' '1.6' '0.2']
#  ['4.8' '3.1' '1.6' '0.2']
#  ['5.4' '3.4' '1.5' '0.4']
#  ['5.2' '4.1' '1.5' '0.1']
#  ['5.5' '4.2' '1.4' '0.2']
#  ['4.9' '3.1' '1.5' '0.1']
#  ['5.0' '3.2' '1.2' '0.2']
#  ['5.5' '3.5' '1.3' '0.2']
#  ['4.9' '3.1' '1.5' '0.1']
#  ['4.4' '3.0' '1.3' '0.2']
#  ['5.1' '3.4' '1.5' '0.2']
#  ['5.0' '3.5' '1.3' '0.3']
#  ['4.5' '2.3' '1.3' '0.3']
#  ['4.4' '3.2' '1.3' '0.2']
#  ['5.0' '3.5' '1.6' '0.6']
#  ['5.1' '3.8' '1.9' '0.4']
#  ['4.8' '3.0' '1.4' '0.3']
#  ['5.1' '3.8' '1.6' '0.2']
#  ['4.6' '3.2' '1.4' '0.2']
#  ['5.3' '3.7' '1.5' '0.2']
#  ['5.0' '3.3' '1.4' '0.2']
#  ['7.0' '3.2' '4.7' '1.4']
#  ['6.4' '3.2' '4.5' '1.5']
#  ['6.9' '3.1' '4.9' '1.5']
#  ['5.5' '2.3' '4.0' '1.3']
#  ['6.5' '2.8' '4.6' '1.5']
#  ['5.7' '2.8' '4.5' '1.3']
#  ['6.3' '3.3' '4.7' '1.6']
#  ['4.9' '2.4' '3.3' '1.0']
#  ['6.6' '2.9' '4.6' '1.3']
#  ['5.2' '2.7' '3.9' '1.4']
#  ['5.0' '2.0' '3.5' '1.0']
#  ['5.9' '3.0' '4.2' '1.5']
#  ['6.0' '2.2' '4.0' '1.0']
#  ['6.1' '2.9' '4.7' '1.4']
#  ['5.6' '2.9' '3.6' '1.3']
#  ['6.7' '3.1' '4.4' '1.4']
#  ['5.6' '3.0' '4.5' '1.5']
#  ['5.8' '2.7' '4.1' '1.0']
#  ['6.2' '2.2' '4.5' '1.5']
#  ['5.6' '2.5' '3.9' '1.1']
#  ['5.9' '3.2' '4.8' '1.8']
#  ['6.1' '2.8' '4.0' '1.3']
#  ['6.3' '2.5' '4.9' '1.5']
#  ['6.1' '2.8' '4.7' '1.2']
#  ['6.4' '2.9' '4.3' '1.3']
#  ['6.6' '3.0' '4.4' '1.4']
#  ['6.8' '2.8' '4.8' '1.4']
#  ['6.7' '3.0' '5.0' '1.7']
#  ['6.0' '2.9' '4.5' '1.5']
#  ['5.7' '2.6' '3.5' '1.0']
#  ['5.5' '2.4' '3.8' '1.1']
#  ['5.5' '2.4' '3.7' '1.0']
#  ['5.8' '2.7' '3.9' '1.2']
#  ['6.0' '2.7' '5.1' '1.6']
#  ['5.4' '3.0' '4.5' '1.5']
#  ['6.0' '3.4' '4.5' '1.6']
#  ['6.7' '3.1' '4.7' '1.5']
#  ['6.3' '2.3' '4.4' '1.3']
#  ['5.6' '3.0' '4.1' '1.3']
#  ['5.5' '2.5' '4.0' '1.3']
#  ['5.5' '2.6' '4.4' '1.2']
#  ['6.1' '3.0' '4.6' '1.4']
#  ['5.8' '2.6' '4.0' '1.2']
#  ['5.0' '2.3' '3.3' '1.0']
#  ['5.6' '2.7' '4.2' '1.3']
#  ['5.7' '3.0' '4.2' '1.2']
#  ['5.7' '2.9' '4.2' '1.3']
#  ['6.2' '2.9' '4.3' '1.3']
#  ['5.1' '2.5' '3.0' '1.1']
#  ['5.7' '2.8' '4.1' '1.3']
#  ['6.3' '3.3' '6.0' '2.5']
#  ['5.8' '2.7' '5.1' '1.9']
#  ['7.1' '3.0' '5.9' '2.1']
#  ['6.3' '2.9' '5.6' '1.8']
#  ['6.5' '3.0' '5.8' '2.2']
#  ['7.6' '3.0' '6.6' '2.1']
#  ['4.9' '2.5' '4.5' '1.7']
#  ['7.3' '2.9' '6.3' '1.8']
#  ['6.7' '2.5' '5.8' '1.8']
#  ['7.2' '3.6' '6.1' '2.5']
#  ['6.5' '3.2' '5.1' '2.0']
#  ['6.4' '2.7' '5.3' '1.9']
#  ['6.8' '3.0' '5.5' '2.1']
#  ['5.7' '2.5' '5.0' '2.0']
#  ['5.8' '2.8' '5.1' '2.4']
#  ['6.4' '3.2' '5.3' '2.3']
#  ['6.5' '3.0' '5.5' '1.8']
#  ['7.7' '3.8' '6.7' '2.2']
#  ['7.7' '2.6' '6.9' '2.3']
#  ['6.0' '2.2' '5.0' '1.5']
#  ['6.9' '3.2' '5.7' '2.3']
#  ['5.6' '2.8' '4.9' '2.0']
#  ['7.7' '2.8' '6.7' '2.0']
#  ['6.3' '2.7' '4.9' '1.8']
#  ['6.7' '3.3' '5.7' '2.1']
#  ['7.2' '3.2' '6.0' '1.8']
#  ['6.2' '2.8' '4.8' '1.8']
#  ['6.1' '3.0' '4.9' '1.8']
#  ['6.4' '2.8' '5.6' '2.1']
#  ['7.2' '3.0' '5.8' '1.6']
#  ['7.4' '2.8' '6.1' '1.9']
#  ['7.9' '3.8' '6.4' '2.0']
#  ['6.4' '2.8' '5.6' '2.2']
#  ['6.3' '2.8' '5.1' '1.5']
#  ['6.1' '2.6' '5.6' '1.4']
#  ['7.7' '3.0' '6.1' '2.3']
#  ['6.3' '3.4' '5.6' '2.4']
#  ['6.4' '3.1' '5.5' '1.8']
#  ['6.0' '3.0' '4.8' '1.8']
#  ['6.9' '3.1' '5.4' '2.1']
#  ['6.7' '3.1' '5.6' '2.4']
#  ['6.9' '3.1' '5.1' '2.3']
#  ['5.8' '2.7' '5.1' '1.9']
#  ['6.8' '3.2' '5.9' '2.3']
#  ['6.7' '3.3' '5.7' '2.5']
#  ['6.7' '3.0' '5.2' '2.3']
#  ['6.3' '2.5' '5.0' '1.9']
#  ['6.5' '3.0' '5.2' '2.0']
#  ['6.2' '3.4' '5.4' '2.3']
#  ['5.9' '3.0' '5.1' '1.8']]

# %% [markdown]
# 3. Display the shape, dimensions and size of iris.

# %%
import numpy as np
iris=np.loadtxt("/content/drive/MyDrive/SEM 5/DA/SOLUTIONSS/iris.data",delimiter=",",dtype='str')
print("Shape:",np.shape(iris))
print("Dimensions:",np.ndim(iris))
print("Size:",np.size(iris))
# Out:
# Shape: (150, 5)
# Dimensions: 2
# Size: 750

# %% [markdown]
# 4. Split iris into three 2-D arrays, each array for a different species. Call them irisl, iris2, iris3.

# %%
import numpy as np
iris=np.loadtxt("/content/drive/MyDrive/SEM 5/DA/SOLUTIONSS/iris.data",delimiter=",",dtype='str')
spc_num=iris[:,4]
#iris1
iris1=iris[spc_num=='Iris-setosa',:4]
#iris2
iris2=iris[spc_num=='Iris-versicolor',:4]
#iris3
iris3=iris[spc_num=='Iris-virginica',:4]

# %% [markdown]
# 5. Print the three arrays irisl, iris2, iris3

# %%
print("\tIRIS 1\n")
print(iris1)
print("\n\tIRIS 2\n")
print(iris2)
print("\n\tIRIS 3\n")
print(iris3)
# Out:
# 	IRIS 1
#
# [['5.1' '3.5' '1.4' '0.2']
#  ['4.9' '3.0' '1.4' '0.2']
#  ['4.7' '3.2' '1.3' '0.2']
#  ['4.6' '3.1' '1.5' '0.2']
#  ['5.0' '3.6' '1.4' '0.2']
#  ['5.4' '3.9' '1.7' '0.4']
#  ['4.6' '3.4' '1.4' '0.3']
#  ['5.0' '3.4' '1.5' '0.2']
#  ['4.4' '2.9' '1.4' '0.2']
#  ['4.9' '3.1' '1.5' '0.1']
#  ['5.4' '3.7' '1.5' '0.2']
#  ['4.8' '3.4' '1.6' '0.2']
#  ['4.8' '3.0' '1.4' '0.1']
#  ['4.3' '3.0' '1.1' '0.1']
#  ['5.8' '4.0' '1.2' '0.2']
#  ['5.7' '4.4' '1.5' '0.4']
#  ['5.4' '3.9' '1.3' '0.4']
#  ['5.1' '3.5' '1.4' '0.3']
#  ['5.7' '3.8' '1.7' '0.3']
#  ['5.1' '3.8' '1.5' '0.3']
#  ['5.4' '3.4' '1.7' '0.2']
#  ['5.1' '3.7' '1.5' '0.4']
#  ['4.6' '3.6' '1.0' '0.2']
#  ['5.1' '3.3' '1.7' '0.5']
#  ['4.8' '3.4' '1.9' '0.2']
#  ['5.0' '3.0' '1.6' '0.2']
#  ['5.0' '3.4' '1.6' '0.4']
#  ['5.2' '3.5' '1.5' '0.2']
#  ['5.2' '3.4' '1.4' '0.2']
#  ['4.7' '3.2' '1.6' '0.2']
#  ['4.8' '3.1' '1.6' '0.2']
#  ['5.4' '3.4' '1.5' '0.4']
#  ['5.2' '4.1' '1.5' '0.1']
#  ['5.5' '4.2' '1.4' '0.2']
#  ['4.9' '3.1' '1.5' '0.1']
#  ['5.0' '3.2' '1.2' '0.2']
#  ['5.5' '3.5' '1.3' '0.2']
#  ['4.9' '3.1' '1.5' '0.1']
#  ['4.4' '3.0' '1.3' '0.2']
#  ['5.1' '3.4' '1.5' '0.2']
#  ['5.0' '3.5' '1.3' '0.3']
#  ['4.5' '2.3' '1.3' '0.3']
#  ['4.4' '3.2' '1.3' '0.2']
#  ['5.0' '3.5' '1.6' '0.6']
#  ['5.1' '3.8' '1.9' '0.4']
#  ['4.8' '3.0' '1.4' '0.3']
#  ['5.1' '3.8' '1.6' '0.2']
#  ['4.6' '3.2' '1.4' '0.2']
#  ['5.3' '3.7' '1.5' '0.2']
#  ['5.0' '3.3' '1.4' '0.2']]
#
# 	IRIS 2
#
# [['7.0' '3.2' '4.7' '1.4']
#  ['6.4' '3.2' '4.5' '1.5']
#  ['6.9' '3.1' '4.9' '1.5']
#  ['5.5' '2.3' '4.0' '1.3']
#  ['6.5' '2.8' '4.6' '1.5']
#  ['5.7' '2.8' '4.5' '1.3']
#  ['6.3' '3.3' '4.7' '1.6']
#  ['4.9' '2.4' '3.3' '1.0']
#  ['6.6' '2.9' '4.6' '1.3']
#  ['5.2' '2.7' '3.9' '1.4']
#  ['5.0' '2.0' '3.5' '1.0']
#  ['5.9' '3.0' '4.2' '1.5']
#  ['6.0' '2.2' '4.0' '1.0']
#  ['6.1' '2.9' '4.7' '1.4']
#  ['5.6' '2.9' '3.6' '1.3']
#  ['6.7' '3.1' '4.4' '1.4']
#  ['5.6' '3.0' '4.5' '1.5']
#  ['5.8' '2.7' '4.1' '1.0']
#  ['6.2' '2.2' '4.5' '1.5']
#  ['5.6' '2.5' '3.9' '1.1']
#  ['5.9' '3.2' '4.8' '1.8']
#  ['6.1' '2.8' '4.0' '1.3']
#  ['6.3' '2.5' '4.9' '1.5']
#  ['6.1' '2.8' '4.7' '1.2']
#  ['6.4' '2.9' '4.3' '1.3']
#  ['6.6' '3.0' '4.4' '1.4']
#  ['6.8' '2.8' '4.8' '1.4']
#  ['6.7' '3.0' '5.0' '1.7']
#  ['6.0' '2.9' '4.5' '1.5']
#  ['5.7' '2.6' '3.5' '1.0']
#  ['5.5' '2.4' '3.8' '1.1']
#  ['5.5' '2.4' '3.7' '1.0']
#  ['5.8' '2.7' '3.9' '1.2']
#  ['6.0' '2.7' '5.1' '1.6']
#  ['5.4' '3.0' '4.5' '1.5']
#  ['6.0' '3.4' '4.5' '1.6']
#  ['6.7' '3.1' '4.7' '1.5']
#  ['6.3' '2.3' '4.4' '1.3']
#  ['5.6' '3.0' '4.1' '1.3']
#  ['5.5' '2.5' '4.0' '1.3']
#  ['5.5' '2.6' '4.4' '1.2']
#  ['6.1' '3.0' '4.6' '1.4']
#  ['5.8' '2.6' '4.0' '1.2']
#  ['5.0' '2.3' '3.3' '1.0']
#  ['5.6' '2.7' '4.2' '1.3']
#  ['5.7' '3.0' '4.2' '1.2']
#  ['5.7' '2.9' '4.2' '1.3']
#  ['6.2' '2.9' '4.3' '1.3']
#  ['5.1' '2.5' '3.0' '1.1']
#  ['5.7' '2.8' '4.1' '1.3']]
#
# 	IRIS 3
#
# [['6.3' '3.3' '6.0' '2.5']
#  ['5.8' '2.7' '5.1' '1.9']
#  ['7.1' '3.0' '5.9' '2.1']
#  ['6.3' '2.9' '5.6' '1.8']
#  ['6.5' '3.0' '5.8' '2.2']
#  ['7.6' '3.0' '6.6' '2.1']
#  ['4.9' '2.5' '4.5' '1.7']
#  ['7.3' '2.9' '6.3' '1.8']
#  ['6.7' '2.5' '5.8' '1.8']
#  ['7.2' '3.6' '6.1' '2.5']
#  ['6.5' '3.2' '5.1' '2.0']
#  ['6.4' '2.7' '5.3' '1.9']
#  ['6.8' '3.0' '5.5' '2.1']
#  ['5.7' '2.5' '5.0' '2.0']
#  ['5.8' '2.8' '5.1' '2.4']
#  ['6.4' '3.2' '5.3' '2.3']
#  ['6.5' '3.0' '5.5' '1.8']
#  ['7.7' '3.8' '6.7' '2.2']
#  ['7.7' '2.6' '6.9' '2.3']
#  ['6.0' '2.2' '5.0' '1.5']
#  ['6.9' '3.2' '5.7' '2.3']
#  ['5.6' '2.8' '4.9' '2.0']
#  ['7.7' '2.8' '6.7' '2.0']
#  ['6.3' '2.7' '4.9' '1.8']
#  ['6.7' '3.3' '5.7' '2.1']
#  ['7.2' '3.2' '6.0' '1.8']
#  ['6.2' '2.8' '4.8' '1.8']
#  ['6.1' '3.0' '4.9' '1.8']
#  ['6.4' '2.8' '5.6' '2.1']
#  ['7.2' '3.0' '5.8' '1.6']
#  ['7.4' '2.8' '6.1' '1.9']
#  ['7.9' '3.8' '6.4' '2.0']
#  ['6.4' '2.8' '5.6' '2.2']
#  ['6.3' '2.8' '5.1' '1.5']
#  ['6.1' '2.6' '5.6' '1.4']
#  ['7.7' '3.0' '6.1' '2.3']
#  ['6.3' '3.4' '5.6' '2.4']
#  ['6.4' '3.1' '5.5' '1.8']
#  ['6.0' '3.0' '4.8' '1.8']
#  ['6.9' '3.1' '5.4' '2.1']
#  ['6.7' '3.1' '5.6' '2.4']
#  ['6.9' '3.1' '5.1' '2.3']
#  ['5.8' '2.7' '5.1' '1.9']
#  ['6.8' '3.2' '5.9' '2.3']
#  ['6.7' '3.3' '5.7' '2.5']
#  ['6.7' '3.0' '5.2' '2.3']
#  ['6.3' '2.5' '5.0' '1.9']
#  ['6.5' '3.0' '5.2' '2.0']
#  ['6.2' '3.4' '5.4' '2.3']
#  ['5.9' '3.0' '5.1' '1.8']]

# %% [markdown]
# 6. Create a 1-D array header having elements "sepal length", "sepal width", "petal length", "petal width", "Species No" in that order

# %%
iris=np.loadtxt("/content/drive/MyDrive/SEM 5/DA/SOLUTIONSS/iris.data",delimiter=",",dtype='str')
header = np.array(["sepal length", "sepal width", "petal length", "petal width", "Species No"])

# %% [markdown]
# 7. Display the array header.

# %%
iris=np.loadtxt("/content/drive/MyDrive/SEM 5/DA/SOLUTIONSS/iris.data",delimiter=",",dtype='str')
header = np.array(["sepal length", "sepal width", "petal length", "petal width", "Species No"])
iris=np.insert(iris,0,header,axis=0)
print(iris)
# Out:
# [['sepal length' 'sepal width' 'petal length' 'petal width' 'Species No']
#  ['5.1' '3.5' '1.4' '0.2' 'Iris-setosa']
#  ['4.9' '3.0' '1.4' '0.2' 'Iris-setosa']
#  ['4.7' '3.2' '1.3' '0.2' 'Iris-setosa']
#  ['4.6' '3.1' '1.5' '0.2' 'Iris-setosa']
#  ['5.0' '3.6' '1.4' '0.2' 'Iris-setosa']
#  ['5.4' '3.9' '1.7' '0.4' 'Iris-setosa']
#  ['4.6' '3.4' '1.4' '0.3' 'Iris-setosa']
#  ['5.0' '3.4' '1.5' '0.2' 'Iris-setosa']
#  ['4.4' '2.9' '1.4' '0.2' 'Iris-setosa']
#  ['4.9' '3.1' '1.5' '0.1' 'Iris-setosa']
#  ['5.4' '3.7' '1.5' '0.2' 'Iris-setosa']
#  ['4.8' '3.4' '1.6' '0.2' 'Iris-setosa']
#  ['4.8' '3.0' '1.4' '0.1' 'Iris-setosa']
#  ['4.3' '3.0' '1.1' '0.1' 'Iris-setosa']
#  ['5.8' '4.0' '1.2' '0.2' 'Iris-setosa']
#  ['5.7' '4.4' '1.5' '0.4' 'Iris-setosa']
#  ['5.4' '3.9' '1.3' '0.4' 'Iris-setosa']
#  ['5.1' '3.5' '1.4' '0.3' 'Iris-setosa']
#  ['5.7' '3.8' '1.7' '0.3' 'Iris-setosa']
#  ['5.1' '3.8' '1.5' '0.3' 'Iris-setosa']
#  ['5.4' '3.4' '1.7' '0.2' 'Iris-setosa']
#  ['5.1' '3.7' '1.5' '0.4' 'Iris-setosa']
#  ['4.6' '3.6' '1.0' '0.2' 'Iris-setosa']
#  ['5.1' '3.3' '1.7' '0.5' 'Iris-setosa']
#  ['4.8' '3.4' '1.9' '0.2' 'Iris-setosa']
#  ['5.0' '3.0' '1.6' '0.2' 'Iris-setosa']
#  ['5.0' '3.4' '1.6' '0.4' 'Iris-setosa']
#  ['5.2' '3.5' '1.5' '0.2' 'Iris-setosa']
#  ['5.2' '3.4' '1.4' '0.2' 'Iris-setosa']
#  ['4.7' '3.2' '1.6' '0.2' 'Iris-setosa']
#  ['4.8' '3.1' '1.6' '0.2' 'Iris-setosa']
#  ['5.4' '3.4' '1.5' '0.4' 'Iris-setosa']
#  ['5.2' '4.1' '1.5' '0.1' 'Iris-setosa']
#  ['5.5' '4.2' '1.4' '0.2' 'Iris-setosa']
#  ['4.9' '3.1' '1.5' '0.1' 'Iris-setosa']
#  ['5.0' '3.2' '1.2' '0.2' 'Iris-setosa']
#  ['5.5' '3.5' '1.3' '0.2' 'Iris-setosa']
#  ['4.9' '3.1' '1.5' '0.1' 'Iris-setosa']
#  ['4.4' '3.0' '1.3' '0.2' 'Iris-setosa']
#  ['5.1' '3.4' '1.5' '0.2' 'Iris-setosa']
#  ['5.0' '3.5' '1.3' '0.3' 'Iris-setosa']
#  ['4.5' '2.3' '1.3' '0.3' 'Iris-setosa']
#  ['4.4' '3.2' '1.3' '0.2' 'Iris-setosa']
#  ['5.0' '3.5' '1.6' '0.6' 'Iris-setosa']
#  ['5.1' '3.8' '1.9' '0.4' 'Iris-setosa']
#  ['4.8' '3.0' '1.4' '0.3' 'Iris-setosa']
#  ['5.1' '3.8' '1.6' '0.2' 'Iris-setosa']
#  ['4.6' '3.2' '1.4' '0.2' 'Iris-setosa']
#  ['5.3' '3.7' '1.5' '0.2' 'Iris-setosa']
#  ['5.0' '3.3' '1.4' '0.2' 'Iris-setosa']
#  ['7.0' '3.2' '4.7' '1.4' 'Iris-versicolor']
#  ['6.4' '3.2' '4.5' '1.5' 'Iris-versicolor']
#  ['6.9' '3.1' '4.9' '1.5' 'Iris-versicolor']
#  ['5.5' '2.3' '4.0' '1.3' 'Iris-versicolor']
#  ['6.5' '2.8' '4.6' '1.5' 'Iris-versicolor']
#  ['5.7' '2.8' '4.5' '1.3' 'Iris-versicolor']
#  ['6.3' '3.3' '4.7' '1.6' 'Iris-versicolor']
#  ['4.9' '2.4' '3.3' '1.0' 'Iris-versicolor']
#  ['6.6' '2.9' '4.6' '1.3' 'Iris-versicolor']
#  ['5.2' '2.7' '3.9' '1.4' 'Iris-versicolor']
#  ['5.0' '2.0' '3.5' '1.0' 'Iris-versicolor']
#  ['5.9' '3.0' '4.2' '1.5' 'Iris-versicolor']
#  ['6.0' '2.2' '4.0' '1.0' 'Iris-versicolor']
#  ['6.1' '2.9' '4.7' '1.4' 'Iris-versicolor']
#  ['5.6' '2.9' '3.6' '1.3' 'Iris-versicolor']
#  ['6.7' '3.1' '4.4' '1.4' 'Iris-versicolor']
#  ['5.6' '3.0' '4.5' '1.5' 'Iris-versicolor']
#  ['5.8' '2.7' '4.1' '1.0' 'Iris-versicolor']
#  ['6.2' '2.2' '4.5' '1.5' 'Iris-versicolor']
#  ['5.6' '2.5' '3.9' '1.1' 'Iris-versicolor']
#  ['5.9' '3.2' '4.8' '1.8' 'Iris-versicolor']
#  ['6.1' '2.8' '4.0' '1.3' 'Iris-versicolor']
#  ['6.3' '2.5' '4.9' '1.5' 'Iris-versicolor']
#  ['6.1' '2.8' '4.7' '1.2' 'Iris-versicolor']
#  ['6.4' '2.9' '4.3' '1.3' 'Iris-versicolor']
#  ['6.6' '3.0' '4.4' '1.4' 'Iris-versicolor']
#  ['6.8' '2.8' '4.8' '1.4' 'Iris-versicolor']
#  ['6.7' '3.0' '5.0' '1.7' 'Iris-versicolor']
#  ['6.0' '2.9' '4.5' '1.5' 'Iris-versicolor']
#  ['5.7' '2.6' '3.5' '1.0' 'Iris-versicolor']
#  ['5.5' '2.4' '3.8' '1.1' 'Iris-versicolor']
#  ['5.5' '2.4' '3.7' '1.0' 'Iris-versicolor']
#  ['5.8' '2.7' '3.9' '1.2' 'Iris-versicolor']
#  ['6.0' '2.7' '5.1' '1.6' 'Iris-versicolor']
#  ['5.4' '3.0' '4.5' '1.5' 'Iris-versicolor']
#  ['6.0' '3.4' '4.5' '1.6' 'Iris-versicolor']
#  ['6.7' '3.1' '4.7' '1.5' 'Iris-versicolor']
#  ['6.3' '2.3' '4.4' '1.3' 'Iris-versicolor']
#  ['5.6' '3.0' '4.1' '1.3' 'Iris-versicolor']
#  ['5.5' '2.5' '4.0' '1.3' 'Iris-versicolor']
#  ['5.5' '2.6' '4.4' '1.2' 'Iris-versicolor']
#  ['6.1' '3.0' '4.6' '1.4' 'Iris-versicolor']
#  ['5.8' '2.6' '4.0' '1.2' 'Iris-versicolor']
#  ['5.0' '2.3' '3.3' '1.0' 'Iris-versicolor']
#  ['5.6' '2.7' '4.2' '1.3' 'Iris-versicolor']
#  ['5.7' '3.0' '4.2' '1.2' 'Iris-versicolor']
#  ['5.7' '2.9' '4.2' '1.3' 'Iris-versicolor']
#  ['6.2' '2.9' '4.3' '1.3' 'Iris-versicolor']
#  ['5.1' '2.5' '3.0' '1.1' 'Iris-versicolor']
#  ['5.7' '2.8' '4.1' '1.3' 'Iris-versicolor']
#  ['6.3' '3.3' '6.0' '2.5' 'Iris-virginica']
#  ['5.8' '2.7' '5.1' '1.9' 'Iris-virginica']
#  ['7.1' '3.0' '5.9' '2.1' 'Iris-virginica']
#  ['6.3' '2.9' '5.6' '1.8' 'Iris-virginica']
#  ['6.5' '3.0' '5.8' '2.2' 'Iris-virginica']
#  ['7.6' '3.0' '6.6' '2.1' 'Iris-virginica']
#  ['4.9' '2.5' '4.5' '1.7' 'Iris-virginica']
#  ['7.3' '2.9' '6.3' '1.8' 'Iris-virginica']
#  ['6.7' '2.5' '5.8' '1.8' 'Iris-virginica']
#  ['7.2' '3.6' '6.1' '2.5' 'Iris-virginica']
#  ['6.5' '3.2' '5.1' '2.0' 'Iris-virginica']
#  ['6.4' '2.7' '5.3' '1.9' 'Iris-virginica']
#  ['6.8' '3.0' '5.5' '2.1' 'Iris-virginica']
#  ['5.7' '2.5' '5.0' '2.0' 'Iris-virginica']
#  ['5.8' '2.8' '5.1' '2.4' 'Iris-virginica']
#  ['6.4' '3.2' '5.3' '2.3' 'Iris-virginica']
#  ['6.5' '3.0' '5.5' '1.8' 'Iris-virginica']
#  ['7.7' '3.8' '6.7' '2.2' 'Iris-virginica']
#  ['7.7' '2.6' '6.9' '2.3' 'Iris-virginica']
#  ['6.0' '2.2' '5.0' '1.5' 'Iris-virginica']
#  ['6.9' '3.2' '5.7' '2.3' 'Iris-virginica']
#  ['5.6' '2.8' '4.9' '2.0' 'Iris-virginica']
#  ['7.7' '2.8' '6.7' '2.0' 'Iris-virginica']
#  ['6.3' '2.7' '4.9' '1.8' 'Iris-virginica']
#  ['6.7' '3.3' '5.7' '2.1' 'Iris-virginica']
#  ['7.2' '3.2' '6.0' '1.8' 'Iris-virginica']
#  ['6.2' '2.8' '4.8' '1.8' 'Iris-virginica']
#  ['6.1' '3.0' '4.9' '1.8' 'Iris-virginica']
#  ['6.4' '2.8' '5.6' '2.1' 'Iris-virginica']
#  ['7.2' '3.0' '5.8' '1.6' 'Iris-virginica']
#  ['7.4' '2.8' '6.1' '1.9' 'Iris-virginica']
#  ['7.9' '3.8' '6.4' '2.0' 'Iris-virginica']
#  ['6.4' '2.8' '5.6' '2.2' 'Iris-virginica']
#  ['6.3' '2.8' '5.1' '1.5' 'Iris-virginica']
#  ['6.1' '2.6' '5.6' '1.4' 'Iris-virginica']
#  ['7.7' '3.0' '6.1' '2.3' 'Iris-virginica']
#  ['6.3' '3.4' '5.6' '2.4' 'Iris-virginica']
#  ['6.4' '3.1' '5.5' '1.8' 'Iris-virginica']
#  ['6.0' '3.0' '4.8' '1.8' 'Iris-virginica']
#  ['6.9' '3.1' '5.4' '2.1' 'Iris-virginica']
#  ['6.7' '3.1' '5.6' '2.4' 'Iris-virginica']
#  ['6.9' '3.1' '5.1' '2.3' 'Iris-virginica']
#  ['5.8' '2.7' '5.1' '1.9' 'Iris-virginica']
#  ['6.8' '3.2' '5.9' '2.3' 'Iris-virginica']
#  ['6.7' '3.3' '5.7' '2.5' 'Iris-virginica']
#  ['6.7' '3.0' '5.2' '2.3' 'Iris-virginica']
#  ['6.3' '2.5' '5.0' '1.9' 'Iris-virginica']
#  ['6.5' '3.0' '5.2' '2.0' 'Iris-virginica']
#  ['6.2' '3.4' '5.4' '2.3' 'Iris-virginica']
#  ['5.9' '3.0' '5.1' '1.8' 'Iris-virginica']]

# %% [markdown]
# 8. Find the max, min, mean and standard deviation for the columns of the iris and store the results in the arrays iris_max, iris_min, iris_avg, iris_std, iris_ var respectively. The results must be rounded to not more than two decimal places

# %%
iris=np.loadtxt("/content/drive/MyDrive/SEM 5/DA/SOLUTIONSS/iris.data",delimiter=",",dtype='str')
iris=iris[:,:4]
iris=np.array(iris,dtype=float)
iris_max=np.max(iris)
print("Maximum:",iris_max)
iris_min=np.min(iris)
print("Minimum:",iris_min)
iris_avg=np.round(np.mean(iris),2)
print("Average:",iris_avg)
iris_std=np.round(np.std(iris),2)
print("Standard Deviation:",iris_std)
iris_var=np.round(iris_std**2,2)
print("Variance:",iris_var)
# Out:
# Maximum: 7.9
# Minimum: 0.1
# Average: 3.46
# Standard Deviation: 1.97
# Variance: 3.88

# %% [markdown]
# 9.Similarly find the max, min, mean and standard deviation for the columns of the irisl, iris2 and iris3 and store the results in the arrays with appropriate names

# %%
iris1=np.array(iris1,dtype=float)
iris2=np.array(iris2,dtype=float)
iris3=np.array(iris3,dtype=float)
iris1_max=np.max(iris1)
print("\tFOR IRIS 1\n")
print("Maximum:",iris1_max)
iris1_min=np.min(iris1)
print("Minimum:",iris1_min)
iris1_avg=np.round(np.mean(iris1),2)
print("Average:",iris1_avg)
iris1_std=np.round(np.std(iris1),2)
print("Standard Deviation:",iris1_std)
iris1_var=np.round(iris1_std**2,2)
print("Variance:",iris1_var)
#iris2
print("\n\tFOR IRIS 2\n")
iris2_max=np.max(iris2)
print("Maximum:",iris2_max)
iris2_min=np.min(iris2)
print("Minimum:",iris2_min)
iris2_avg=np.round(np.mean(iris2),2)
print("Average:",iris2_avg)
iris2_std=np.round(np.std(iris2),2)
print("Standard Deviation:",iris2_std)
iris2_var=np.round(iris2_std**2,2)
print("Variance:",iris2_var)
print("\n\tFOR IRIS 3\n")
iris3_max=np.max(iris3)
print("Maximum:",iris3_max)
iris3_min=np.min(iris3)
print("Minimum:",iris3_min)
iris3_avg=np.round(np.mean(iris3),2)
print("Average:",iris3_avg)
iris3_std=np.round(np.std(iris3),2)
print("Standard Deviation:",iris3_std)
iris3_var=np.round(iris3_std**2,2)
print("Variance:",iris3_var)
# Out:
# 	FOR IRIS 1
#
# Maximum: 5.8
# Minimum: 0.1
# Average: 2.53
# Standard Deviation: 1.84
# Variance: 3.39
#
# 	FOR IRIS 2
#
# Maximum: 7.0
# Minimum: 1.0
# Average: 3.57
# Standard Deviation: 1.76
# Variance: 3.1
#
# 	FOR IRIS 3
#
# Maximum: 7.9
# Minimum: 1.4
# Average: 4.28
# Standard Deviation: 1.91
# Variance: 3.65

# %%
timport pandas as pd
iris=np.loadtxt("/content/drive/MyDrive/SEM 5/DA/SOLUTIONSS/iris.data",delimiter=",",dtype='str')
header = np.array(["sepal length", "sepal width", "petal length", "petal width", "Species No"])
iris=np.insert(iris,0,header,axis=0)
iris_df=pd.DataFrame(iris)
final_df=pd.DataFrame()
details=['sepal length','sepal width','petal length','petal width']
final_df[" "]=details


print(final_df)
# Out:
#
# 0  sepal length
# 1   sepal width
# 2  petal length
# 3   petal width

# %%
import pandas as pd

# Create an empty DataFrame
empty_df = pd.DataFrame()

# Create a new DataFrame or Series with the data you want to add horizontally
data_to_add = pd.Series([1, 2, 3])

# Concatenate (join) the empty DataFrame and the new data horizontally
result_df = pd.concat([empty_df, data_to_add], axis=1)

# Optionally, you can reset the column names if needed
result_df.columns = ['new_column_name']



final_df=pd.concat([final_df,iris_df.iloc[0]])
names=pd.Series(["Iris-setosa"," Iris-versicolor","Iris-virginica"])
final_df=pd.concat([final_df,names],axis=1)
print(result_df)
# Out:
#    new_column_name
# 0                1
# 1                2
# 2                3
